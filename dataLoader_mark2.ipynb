# %%
from utils.DataLoader import DataLoader

# %%
d = DataLoader("./data")

# %%
from utils.DataLoader import show_image_from_memory

# %%
show_image_from_memory(d.anorm_img_array[0])

# %%
subset = d.get_sub_dataset(28)

# %%
subset.shape
# Out:
# (50000, 28, 28)
